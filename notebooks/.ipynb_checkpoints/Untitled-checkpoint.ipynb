# %%
import sys
import re
import json

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import torch
from torch import nn

from pathlib import Path

ROOT = Path("..").resolve()  # repo root
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from check_dataset import summarize_dataset, print_report, plot_global_hist

ARTIFACTS = ROOT / "artifacts"
npz_paths = sorted(ARTIFACTS.glob("*.npz"))

len16_main = []
len16_hist = []
len8_hist = []

for p in ARTIFACTS.glob("*.npz"):
    stem = p.stem
    if "len16" in stem and "hist" in stem and "zh" in stem:
        len16_hist.append(p)
    elif "len8" in stem and "hist" in stem and "en" in stem:
        len8_hist.append(p)
    elif "len16" in stem:
        len16_main.append(p)

# %%
EN_ROLLOUTS = ROOT / 'rollouts' / 'en'

paths = list(EN_ROLLOUTS.glob('*.json'))

def sort_key(p: Path):
    # expect like en_len16_rollouts32.json
    stem = p.stem
    for part in stem.split('_'):
        if part.startswith('len'):
            try:
                return int(part.removeprefix('len'))
            except ValueError:
                return 0
    return 0

def human_title(path: Path) -> str:
    # expects stems like en_len16_rollouts32
    stem = path.stem
    parts = stem.split("_")
    lang = parts[0].upper() if parts else stem
    length = None
    rollouts = None
    for part in parts:
        if part.startswith("len"):
            try: length = int(part.removeprefix("len"))
            except ValueError: pass
        if part.startswith("rollouts"):
            try: rollouts = int(part.removeprefix("rollouts"))
            except ValueError: pass
    title = "Next-token probability for tracked integers (renormalized)"
    if rollouts is not None:
        title += f" over {rollouts} runs"
    title += f": {lang}"
    if length is not None:
        title += f" length {length}"
    return title

for path in sorted(paths, key=sort_key):
    data = json.loads(path.read_text())
    steps = data['per_step_probs']
    ints = sorted(steps[0].keys())
    mat = np.array([[step[i] for i in ints] for step in steps], dtype=np.float32)
    mat_rel = mat / (mat.sum(axis=1, keepdims=True) + 1e-12)

    vmax = np.percentile(mat_rel, 99.5)
    norm = colors.PowerNorm(gamma=0.2, vmin=0, vmax=vmax)

    plt.figure(figsize=(10, 4))
    im = plt.imshow(
        mat_rel.T,
        aspect='auto',
        origin='lower',
        extent=[0, mat.shape[0], min(ints), max(ints)],
        cmap='magma',
        norm=norm,
    )
    plt.colorbar(im, label='relative prob (tracked ints)')
    plt.xlabel('step')
    plt.ylabel('integer')

    plt.title(human_title(path))
    plt.tight_layout()
    plt.savefig(f"{path.name[:-5]}-heatmap.png", dpi=300, bbox_inches="tight")
    plt.show()

# %%
ZH_ROLLOUTS = ROOT / 'rollouts' / 'zh'

paths = list(ZH_ROLLOUTS.glob('*.json'))

def sort_key(p: Path):
    # expect like en_len16_rollouts32.json
    stem = p.stem
    for part in stem.split('_'):
        if part.startswith('len'):
            try:
                return int(part.removeprefix('len'))
            except ValueError:
                return 0
    return 0

for path in sorted(paths, key=sort_key):
    data = json.loads(path.read_text())
    steps = data['per_step_probs']
    ints = sorted(steps[0].keys())
    mat = np.array([[step[i] for i in ints] for step in steps], dtype=np.float32)
    mat_rel = mat / (mat.sum(axis=1, keepdims=True) + 1e-12)

    vmax = np.percentile(mat_rel, 99.5)
    norm = colors.PowerNorm(gamma=0.2, vmin=0, vmax=vmax)

    plt.figure(figsize=(10, 4))
    im = plt.imshow(
        mat_rel.T,
        aspect='auto',
        origin='lower',
        extent=[0, mat.shape[0], min(ints), max(ints)],
        cmap='magma',
        norm=norm,
    )
    plt.colorbar(im, label='relative prob (tracked ints)')
    plt.xlabel('step')
    plt.ylabel('integer')
    plt.title(f"{path.name} – relative prob (high-contrast)")
    plt.tight_layout()
    plt.show()

# %%
EN_ROLLOUTS = ROOT / 'rollouts' / 'en'
ZH_ROLLOUTS = ROOT / 'rollouts' / 'zh'

def sort_key(p: Path):
    stem = p.stem  # e.g., en_len16_rollouts32
    for part in stem.split('_'):
        if part.startswith('len'):
            try:
                return int(part.removeprefix('len'))
            except ValueError:
                return 0
    return 0

def load_entropy(path: Path):
    data = json.loads(path.read_text())
    steps = data['per_step_probs']
    ints = sorted(steps[0].keys())
    mat = np.array([[step[i] for i in ints] for step in steps], dtype=np.float32)
    mat_rel = mat / (mat.sum(axis=1, keepdims=True) + 1e-12)
    entropy = -(mat_rel * np.log(mat_rel + 1e-12)).sum(axis=1)
    return entropy

plt.figure(figsize=(8,4))

for lang, base in [('en', EN_ROLLOUTS), ('zh', ZH_ROLLOUTS)]:
    for path in sorted(base.glob('*.json'), key=sort_key):
        length = sort_key(path)
        entropy = load_entropy(path)
        plt.plot(range(len(entropy)), entropy, marker='o', label=f"{lang}_len{length}")

plt.xlabel('Step')
plt.ylabel('Entropy (nats) over tracked integers')
plt.title('Entropy by step (English and Simplfied Chinese rollouts)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
paths = list(ZH_ROLLOUTS.glob('*.json'))

def sort_key(p: Path):
    # expect like zh_len16_rollouts32.json
    stem = p.stem
    for part in stem.split('_'):
        if part.startswith('len'):
            try:
                return int(part.removeprefix('len'))
            except ValueError:
                return 0
    return 0

plt.figure(figsize=(8,4))
for path in sorted(paths, key=sort_key):
    data = json.loads(path.read_text())
    steps = data['per_step_probs']
    ints = sorted(steps[0].keys())
    mat = np.array([[step[i] for i in ints] for step in steps], dtype=np.float32)
    mat_rel = mat / (mat.sum(axis=1, keepdims=True) + 1e-12)
    entropy = -(mat_rel * np.log(mat_rel + 1e-12)).sum(axis=1)
    plt.plot(range(mat.shape[0]), entropy, marker='o', label=path.stem)

plt.xlabel('step')
plt.ylabel('entropy (nats) over tracked ints')
plt.title('Entropy by step (EN rollouts)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
from pathlib import Path
import json, numpy as np, matplotlib.pyplot as plt

EN_ROLLOUTS = ROOT / 'rollouts' / 'en'
ZH_ROLLOUTS = ROOT / 'rollouts' / 'zh'

def sort_key(p: Path):
    stem = p.stem  # e.g., en_len16_rollouts32
    for part in stem.split('_'):
        if part.startswith('len'):
            try:
                return int(part.removeprefix('len'))
            except ValueError:
                return 0
    return 0

def load_entropy(path: Path):
    data = json.loads(path.read_text())
    steps = data['per_step_probs']
    ints = sorted(steps[0].keys())
    mat = np.array([[step[i] for i in ints] for step in steps], dtype=np.float32)
    mat_rel = mat / (mat.sum(axis=1, keepdims=True) + 1e-12)
    entropy = -(mat_rel * np.log(mat_rel + 1e-12)).sum(axis=1)
    return entropy

plt.figure(figsize=(8,4))

avg_ent_by_lang = {"en": {}, "zh": {}}
med_ent_by_lang = {"en": {}, "zh": {}}
std_ent_by_lang = {"en": {}, "zh": {}}

for lang, base in [('en', EN_ROLLOUTS), ('zh', ZH_ROLLOUTS)]:
    for path in sorted(base.glob('*.json'), key=sort_key):
        length = sort_key(path)
        entropy = load_entropy(path)
        plt.plot(range(len(entropy)), entropy, marker='o', label=f"{lang}_len{length}")
        avg_ent_by_lang[lang][length] = float(entropy.mean())
        med_ent_by_lang[lang][length] = float(np.median(entropy))
        std_ent_by_lang[lang][length] = float(entropy.std())

plt.xlabel('Step')
plt.ylabel('Entropy (nats) over tracked integers')
plt.title('Entropy by step (English and Chinese rollouts)')
plt.legend()
plt.tight_layout()
plt.show()

# Print stats per length and abs differences
en_avg, zh_avg = avg_ent_by_lang["en"], avg_ent_by_lang["zh"]
en_med, zh_med = med_ent_by_lang["en"], med_ent_by_lang["zh"]
en_std, zh_std = std_ent_by_lang["en"], std_ent_by_lang["zh"]
common_lengths = sorted(set(en_avg.keys()) & set(zh_avg.keys()))

print("Entropy stats (nats) per length:")
for L in common_lengths:
    diff_mean = abs(en_avg[L] - zh_avg[L])
    diff_med = abs(en_med[L] - zh_med[L])
    print(
        f"  len {L}: "
        f"mean en={en_avg[L]:.4f} (std={en_std[L]:.4f}), "
        f"zh={zh_avg[L]:.4f} (std={zh_std[L]:.4f}), |Δmean|={diff_mean:.4f}; "
        f"median en={en_med[L]:.4f}, zh={zh_med[L]:.4f}, |Δmedian|={diff_med:.4f}"
    )
# Out:
# Entropy stats (nats) per length:
#   len 2: mean en=2.8586 (std=0.0228), zh=2.3395 (std=0.0110), |Δmean|=0.5192; median en=2.8586, zh=2.3395, |Δmedian|=0.5192
#   len 4: mean en=2.8651 (std=0.0298), zh=2.3454 (std=0.0136), |Δmean|=0.5197; median en=2.8661, zh=2.3423, |Δmedian|=0.5238
#   len 8: mean en=2.8370 (std=0.1802), zh=2.3769 (std=0.0187), |Δmean|=0.4601; median en=2.9039, zh=2.3761, |Δmedian|=0.5278
#   len 16: mean en=2.5949 (std=0.4039), zh=2.3734 (std=0.0243), |Δmean|=0.2215; median en=2.6817, zh=2.3638, |Δmedian|=0.3179

# %%
for path in npz_paths:
    if not path.exists():
        print(f"Missing: {path}")
        continue
    summary = summarize_dataset(path)
    print_report(summary)
    print()
# Out:
# File: /Users/kevwjin/Documents/02_Areas/Sjsu/Fall2025/Cs228_BioSecAi/Research/artifacts/en-len16-n8192-rep1.npz
#   shape=(8192, 16), dtype=int64
#   min=1, max=99
#   unique rows=8192, duplicate rows=0, duplicate entries=0
#   global uniform test: chi2=241280.69, dof=98, p=0.000e+00
#   value frequency outliers (value, count, z):
#     1: count=13, z=-36.03
#     2: count=354, z=-26.66
#     3: count=130, z=-32.81
#     5: count=231, z=-30.04
#     6: count=93, z=-33.83
#     7: count=602, z=-19.84
#     8: count=418, z=-24.90
#     9: count=410, z=-25.12
#     10: count=17, z=-35.92
#     11: count=4285, z=81.38
#     12: count=447, z=-24.10
#     13: count=7720, z=175.78
#     pos 2: unique=71, max_count=1788 (value=28), zero_bins=28, min_nonzero=1, uniform[chi2=85084.90, dof=98, p=0.000e+00], vs_global[chi2=14167.67, dof=97, p=0.000e+00]
#     pos 3: unique=81, max_count=2555 (value=67), zero_bins=18, min_nonzero=1, uniform[chi2=96813.07, dof=98, p=0.000e+00], vs_global[chi2=17196.53, dof=97, p=0.000e+00]
#     pos 4: unique=87, max_count=1252 (value=67), zero_bins=12, min_nonzero=1, uniform[chi2=47463.43, dof=98, p=0.000e+00], vs_global[chi2=6303.07, dof=97, p=0.000e+00]
#     pos 5: unique=85, max_count=1136 (value=67), zero_bins=14, min_nonzero=1, uniform[chi2=36784.28, dof=98, p=0.000e+00], vs_global[chi2=3942.02, dof=97, p=0.000e+00]
#     pos 6: unique=88, max_count=847 (value=67), zero_bins=11, min_nonzero=1, uniform[chi2=33506.02, dof=98, p=0.000e+00], vs_global[chi2=3152.00, dof=97, p=0.000e+00]
#     pos 7: unique=86, max_count=873 (value=85), zero_bins=13, min_nonzero=1, uniform[chi2=29237.83, dof=98, p=0.000e+00], vs_global[chi2=2630.00, dof=97, p=0.000e+00]
#     pos 8: unique=90, max_count=663 (value=85), zero_bins=9, min_nonzero=1, uniform[chi2=23298.56, dof=98, p=0.000e+00], vs_global[chi2=2283.59, dof=97, p=0.000e+00]
#     pos 9: unique=91, max_count=659 (value=46), zero_bins=8, min_nonzero=1, uniform[chi2=18285.59, dof=98, p=0.000e+00], vs_global[chi2=2100.34, dof=97, p=0.000e+00]
#     pos 10: unique=91, max_count=717 (value=46), zero_bins=8, min_nonzero=1, uniform[chi2=18007.71, dof=98, p=0.000e+00], vs_global[chi2=2125.04, dof=97, p=0.000e+00]
#     pos 11: unique=94, max_count=779 (value=98), zero_bins=5, min_nonzero=1, uniform[chi2=17620.46, dof=98, p=0.000e+00], vs_global[chi2=2607.11, dof=97, p=0.000e+00]
#     pos 12: unique=95, max_count=576 (value=98), zero_bins=4, min_nonzero=1, uniform[chi2=14596.64, dof=98, p=0.000e+00], vs_global[chi2=2906.76, dof=97, p=0.000e+00]
#     pos 13: unique=93, max_count=564 (value=11), zero_bins=6, min_nonzero=1, uniform[chi2=12342.48, dof=98, p=0.000e+00], vs_global[chi2=3338.79, dof=97, p=0.000e+00]
#     pos 14: unique=94, max_count=454 (value=46), zero_bins=5, min_nonzero=1, uniform[chi2=10806.74, dof=98, p=0.000e+00], vs_global[chi2=5473.60, dof=97, p=0.000e+00]
#     pos 15: unique=89, max_count=478 (value=98), zero_bins=10, min_nonzero=1, uniform[chi2=12407.69, dof=98, p=0.000e+00], vs_global[chi2=8125.54, dof=97, p=0.000e+00]
#
# File: /Users/kevwjin/Documents/02_Areas/Sjsu/Fall2025/Cs228_BioSecAi/Research/artifacts/en-len16-n8192-rep2.npz
#   shape=(8192, 16), dtype=int64
#   min=1, max=99
#   unique rows=8192, duplicate rows=0, duplicate entries=0
#   global uniform test: chi2=241631.00, dof=98, p=0.000e+00
#   value frequency outliers (value, count, z):
#     1: count=11, z=-36.08
#     2: count=315, z=-27.73
#     3: count=132, z=-32.76
#     5: count=237, z=-29.87
#     6: count=97, z=-33.72
#     7: count=621, z=-19.32
#     pos 1: unique=52, max_count=2420 (value=91), zero_bins=47, min_nonzero=1, uniform[chi2=134282.87, dof=98, p=0.000e+00], vs_global[chi2=32674.78, dof=98, p=0.000e+00]
#     pos 2: unique=70, max_count=1750 (value=28), zero_bins=29, min_nonzero=1, uniform[chi2=83231.14, dof=98, p=0.000e+00], vs_global[chi2=14014.17, dof=98, p=0.000e+00]
#     pos 3: unique=77, max_count=2487 (value=67), zero_bins=22, min_nonzero=1, uniform[chi2=91986.48, dof=98, p=0.000e+00], vs_global[chi2=16460.28, dof=98, p=0.000e+00]
#     pos 4: unique=84, max_count=1278 (value=67), zero_bins=15, min_nonzero=1, uniform[chi2=46898.19, dof=98, p=0.000e+00], vs_global[chi2=6573.24, dof=98, p=0.000e+00]
#     pos 5: unique=87, max_count=1087 (value=67), zero_bins=12, min_nonzero=1, uniform[chi2=36967.32, dof=98, p=0.000e+00], vs_global[chi2=3879.38, dof=98, p=0.000e+00]
#     pos 6: unique=90, max_count=845 (value=67), zero_bins=9, min_nonzero=1, uniform[chi2=32848.21, dof=98, p=0.000e+00], vs_global[chi2=2852.17, dof=98, p=0.000e+00]
#     pos 7: unique=86, max_count=894 (value=85), zero_bins=13, min_nonzero=1, uniform[chi2=29656.70, dof=98, p=0.000e+00], vs_global[chi2=2449.54, dof=98, p=0.000e+00]
#     pos 8: unique=94, max_count=620 (value=46), zero_bins=5, min_nonzero=1, uniform[chi2=23498.30, dof=98, p=0.000e+00], vs_global[chi2=2139.50, dof=98, p=0.000e+00]
#     pos 9: unique=86, max_count=680 (value=46), zero_bins=13, min_nonzero=1, uniform[chi2=18439.75, dof=98, p=0.000e+00], vs_global[chi2=2190.82, dof=98, p=0.000e+00]
#     pos 10: unique=93, max_count=704 (value=46), zero_bins=6, min_nonzero=1, uniform[chi2=17996.76, dof=98, p=0.000e+00], vs_global[chi2=2106.56, dof=98, p=0.000e+00]
#     pos 11: unique=93, max_count=812 (value=98), zero_bins=6, min_nonzero=1, uniform[chi2=17968.05, dof=98, p=0.000e+00], vs_global[chi2=2492.03, dof=98, p=0.000e+00]
#     pos 12: unique=94, max_count=553 (value=46), zero_bins=5, min_nonzero=1, uniform[chi2=14354.81, dof=98, p=0.000e+00], vs_global[chi2=3059.53, dof=98, p=0.000e+00]
#     pos 13: unique=93, max_count=572 (value=11), zero_bins=6, min_nonzero=1, uniform[chi2=11870.15, dof=98, p=0.000e+00], vs_global[chi2=3597.21, dof=98, p=0.000e+00]
#     pos 14: unique=94, max_count=437 (value=11), zero_bins=5, min_nonzero=1, uniform[chi2=10473.25, dof=98, p=0.000e+00], vs_global[chi2=5657.51, dof=98, p=0.000e+00]
#     pos 15: unique=89, max_count=456 (value=98), zero_bins=10, min_nonzero=1, uniform[chi2=12140.29, dof=98, p=0.000e+00], vs_global[chi2=8257.20, dof=98, p=0.000e+00]
#
# File: /Users/kevwjin/Documents/02_Areas/Sjsu/Fall2025/Cs228_BioSecAi/Research/artifacts
#     pos 2: unique=88, max_count=1264 (value=67), zero_bins=11, min_nonzero=1, uniform[chi2=32473.85, dof=98, p=0.000e+00], vs_global[chi2=3249.87, dof=98, p=0.000e+00]
#     pos 3: unique=91, max_count=1110 (value=67), zero_bins=8, min_nonzero=1, uniform[chi2=23834.45, dof=98, p=0.000e+00], vs_global[chi2=1517.06, dof=98, p=5.588e-253]
#     pos 4: unique=84, max_count=949 (value=67), zero_bins=15, min_nonzero=1, uniform[chi2=20320.36, dof=98, p=0.000e+00], vs_global[chi2=1559.97, dof=98, p=1.025e-261]
#     pos 5: unique=88, max_count=768 (value=67), zero_bins=11, min_nonzero=1, uniform[chi2=17060.35, dof=98, p=0.000e+00], vs_global[chi2=1014.05, dof=98, p=3.914e-152]
#     pos 6: unique=84, max_count=526 (value=67), zero_bins=15, min_nonzero=1, uniform[chi2=15243.93, dof=98, p=0.000e+00], vs_global[chi2=758.59, dof=98, p=1.071e-102]
#     pos 7: unique=88, max_count=583 (value=85), zero_bins=11, min_nonzero=1, uniform[chi2=15117.30, dof=98, p=0.000e+00], vs_global[chi2=652.52, dof=98, p=8.567e-83]
#     pos 8: unique=90, max_count=542 (value=85), zero_bins=9, min_nonzero=1, uniform[chi2=12693.81, dof=98, p=0.000e+00], vs_global[chi2=503.44, dof=98, p=8.320e-56]
#     pos 9: unique=90, max_count=435 (value=85), zero_bins=9, min_nonzero=1, uniform[chi2=10785.23, dof=98, p=0.000e+00], vs_global[chi2=685.41, dof=98, p=6.510e-89]
#     pos 10: unique=91, max_count=450 (value=46), zero_bins=8, min_nonzero=1, uniform[chi2=9808.65, dof=98, p=0.000e+00], vs_global[chi2=853.96, dof=98, p=6.045e-121]
#     pos 11: unique=88, max_count=424 (value=98), zero_bins=11, min_nonzero=1, uniform[chi2=10354.57, dof=98, p=0.000e+00], vs_global[chi2=922.29, dof=98, p=3.511e-134]
#     pos 12: unique=93, max_count=372 (value=46), zero_bins=6, min_nonzero=1, uniform[chi2=8689.82, dof=98, p=0.000e+00], vs_global[chi2=1156.84, dof=98, p=2.125e-180]
#     pos 13: unique=96, max_count=357 (value=46), zero_bins=3, min_nonzero=1, uniform[chi2=7735.30, dof=98, p=0.000e+00], vs_global[chi2=1583.92, dof=98, p=1.338e-266]
#     pos 14: unique=93, max_count=310 (value=46), zero_bins=6, min_nonzero=1, uniform[chi2=7076.48, dof=98, p=0.000e+00], vs_global[chi2=2811.71, dof=98, p=0.000e+00]
#     pos 15: unique=93, max_count=468 (value=98), zero_bins=6, min_nonzero=1, uniform[chi2=9526.24, dof=98, p=0.000e+00], vs_global[chi2=4281.69, dof=98, p=0.000e+00]
#
# File: /Users/kevwjin/Documents/02_Areas/Sjsu/Fall2025/Cs228_BioSecAi/Research/artifacts
#     pos 1: unique=75, max_count=1252 (value=67), zero_bins=24, min_nonzero=1, uniform[chi2=54893.91, dof=98, p=0.000e+00], vs_global[chi2=5445.67, dof=94, p=0.000e+00]
#     pos 2: unique=78, max_count=1429 (value=67), zero_bins=21, min_nonzero=1, uniform[chi2=42461.61, dof=98, p=0.000e+00], vs_global[chi2=2075.93, dof=94, p=0.000e+00]
#     pos 3: unique=85, max_count=1146 (value=67), zero_bins=14, min_nonzero=1, uniform[chi2=27204.27, dof=98, p=0.000e+00], vs_global[chi2=673.16, dof=94, p=2.477e-88]
#     pos 4: unique=87, max_count=800 (value=67), zero_bins=12, min_nonzero=1, uniform[chi2=19497.43, dof=98, p=0.000e+00], vs_global[chi2=696.32, dof=94, p=1.091e-92]
#     pos 5: unique=83, max_count=521 (value=85), zero_bins=16, min_nonzero=1, uniform[chi2=15433.13, dof=98, p=0.000e+00], vs_global[chi2=1451.53, dof=94, p=4.891e-242]
#     pos 6: unique=88, max_count=544 (value=85), zero_bins=11, min_nonzero=1, uniform[chi2=14748.74, dof=98, p=0.000e+00], vs_global[chi2=1911.93, dof=94, p=0.000e+00]
#     pos 7: unique=90, max_count=618 (value=98), zero_bins=9, min_nonzero=1, uniform[chi2=14746.15, dof=98, p=0.000e+00], vs_global[chi2=4654.50, dof=94, p=0.000e+00]
#
# File: /Users/kevwjin/Documents/02_Areas/Sjsu/Fall2025/Cs228_BioSecAi/Research/artifacts/prng-len16-n8192-rep1.npz
#   shape=(8192, 16), dtype=int64
#   min=1, max=100
#   unique rows=8192, duplicate rows=0, duplicate entries=0
#   global uniform test: chi2=81.68, dof=99, p=8.967e-01
#   value frequency outliers: none
#   per-position summary:
#     pos 0: unique=100, max_count=107 (value=81), zero_bins=0, min_nonzero=62, uniform[chi2=101.24, dof=99, p=4.187e-01], vs_global[chi2=100.97, dof=99, p=4.259e-01]
#     pos 1: unique=100, max_count=110 (value=29), zero_bins=0, min_nonzero=63, uniform[chi2=117.84, dof=99, p=9.528e-02], vs_global[chi2=108.28, dof=99, p=2.461e-01]
#     pos 2: unique=100, max_count=103 (value=43), zero_bins=0, min_nonzero=64, uniform[chi2=89.20, dof=99, p=7.495e-01], vs_global[chi2=93.39, dof=99, p=6.400e-01]
#     pos 3: unique=100, max_count=101 (value=21), zero_bins=0, min_nonzero=61, uniform[chi2=91.06, dof=99, p=7.029e-01], vs_global[chi2=85.70, dof=99, p=8.272e-01]
#     pos 4: unique=100, max_count=103 (value=47), zero_bins=0, min_nonzero=50, uniform[chi2=115.64, dof=99, p=1.212e-01], vs_global[chi2=106.60, dof=99, p=2.829e-01]
#     pos 5: unique=100, max_count=102 (value=76), zero_bins=0, min_nonzero=64, uniform[chi2=74.97, dof=99, p=9.657e-01], vs_global[chi2=74.05, dof=99, p=9.713e-01]
#     pos 6: unique=100, max_count=102 (value=30), zero_bins=0, min_nonzero=62, uniform[chi2=113.13, dof=99, p=1.570e-01], vs_global[chi2=104.87, dof=99, p=3.241e-01]
#     pos 7: unique=100, max_count=117 (value=46), zero_bins=0, min_nonzero=63, uniform[chi2=92.01, dof=99, p=6.777e-01], vs_global[chi2=80.38, dof=99, p=9.145e-01]
#     pos 8: unique=100, max_count=102 (value=88), zero_bins=0, min_nonzero=62, uniform[chi2=85.71, dof=99, p=8.270e-01], vs_global[chi2=81.74, dof=99, p=8.959e-01]
#     pos 9: unique=100, max_count=106 (value=9), zero_bins=0, min_nonzero=57, uniform[chi2=80.36, dof=99, p=9.146e-01], vs_global[chi2=78.73, dof=99, p=9.337e-01]
#     pos 10: unique=100, max_count=105 (value=26), zero_bins=0, min_nonzero=55, uniform[chi2=107.56, dof=99, p=2.615e-01], vs_global[chi2=96.85, dof=99, p=5.423e-01]
#     pos 11: unique=100, max_count=107 (value=68), zero_bins=0, min_nonzero=56, uniform[chi2=119.82, dof=99, p=7.587e-02], vs_global[chi2=118.06, dof=99, p=9.298e-02]
#     pos 12: unique=100, max_count=106 (value=23), zero_bins=0, min_nonzero=61, uniform[chi2=114.32, dof=99, p=1.391e-01], vs_global[chi2=105.47, dof=99, p=3.095e-01]
#     pos 13: unique=100, max_count=103 (value=10), zero_bins=0, min_nonzero=55, uniform[chi2=82.90, dof=99, p=8.779e-01], vs_global[chi2=79.82, dof=99, p=9.213e-01]
#     pos 14: unique=100, max_count=112 (value=74), zero_bins=0, min_nonzero=59, uniform[chi2=111.15, dof=99, p=1.901e-01], vs_global[chi2=107.82, dof=99, p=2.558e-01]
#     pos 15: unique=100, max_count=108 (value=21), zero_bins=0, min_nonzero=64, uniform[chi2=87.17, dof=99, p=7.963e-01], vs_global[chi2=80.89, dof=99, p=9.077e-01]
#
# File: /Users/kevwjin/Documents/02_Areas/Sjsu/Fall2025/Cs228_BioSecAi/Research/artifacts/prng-len16-n8192-rep2.npz
#   shape=(8192, 16), dtype=int64
#   min=1, max=100
#   unique rows=8192, duplicate rows=0, duplicate entries=0
#   global uniform test: chi2=90.59, dof=99, p=7.150e-01
#   value frequency outliers: none
#   per-position summary:
#     pos 0: unique=100, max_count=111 (value=27), zero_bins=0, min_nonzero=57, uniform[chi2=108.02, dof=99, p=2.515e-01], vs_global[chi2=98.19, dof=99, p=5.042e-01]
#     pos 1: unique=100, max_count=102 (value=67), zero_bins=0, min_nonzero=61, uniform[chi2=94.77, dof=99, p=6.016e-01], vs_global[chi2=82.96, dof=99, p=8.770e-01]
#     pos 2: unique=100, max_count=102 (value=33), zero_bins=0, min_nonzero=65, uniform[chi2=99.77, dof=99, p=4.593e-01], vs_global[chi2=93.68, dof=99, p=6.321e-01]
#     pos 3: unique=100, max_count=101 (value=34), zero_bins=0, min_nonzero=62, uniform[chi2=86.54, dof=99, p=8.100e-01], vs_global[chi2=86.00, dof=99, p=8.211e-01]
#     pos 4: unique=100, max_count=105 (value=39), zero_bins=0, min_nonzero=59, uniform[chi2=92.35, dof=99, p=6.685e-01], vs_global[chi2=90.40, dof=99, p=7.197e-01]
#     pos 5: unique=100, max_count=102 (value=39), zero_bins=0, min_nonzero=48, uniform[chi2=94.74, dof=99, p=6.023e-01], vs_global[chi2=84.86, dof=99, p=8.436e-01]
#     pos 6: unique=100, max_count=103 (value=48), zero_bins=0, min_nonzero=61, uniform[chi2=101.31, dof=99, p=4.167e-01], vs_global[chi2=101.08, dof=99, p=4.230e-01]
#     pos 7: unique=100, max_count=107 (value=93), zero_bins=0, min_nonzero=60, uniform[chi2=102.70, dof=99, p=3.794e-01], vs_global[chi2=101.39, dof=99, p=4.145e-01]
#     pos 8: unique=100, max_count=116 (value=90), zero_bins=0, min_nonzero=61, uniform[chi2=121.55, dof=99, p=6.161e-02], vs_global[chi2=112.48, dof=99, p=1.673e-01]
#     pos 9: unique=100, max_count=105 (value=25), zero_bins=0, min_nonzero=60, uniform[chi2=88.49, dof=99, p=7.664e-01], vs_global[chi2=94.41, dof=99, p=6.117e-01]
#     pos 10: unique=100, max_count=105 (value=78), zero_bins=0, min_nonzero=66, uniform[chi2=107.10, dof=99, p=2.718e-01], vs_global[chi2=99.19, dof=99, p=4.756e-01]
#     pos 11: unique=100, max_count=110 (value=5), zero_bins=0, min_nonzero=56, uniform[chi2=104.75, dof=99, p=3.269e-01], vs_global[chi2=95.33, dof=99, p=5.857e-01]
#     pos 12: unique=100, max_count=106 (value=73), zero_bins=0, min_nonzero=60, uniform[chi2=101.58, dof=99, p=4.094e-01], vs_global[chi2=95.27, dof=99, p=5.876e-01]
#     pos 13: unique=100, max_count=115 (value=93), zero_bins=0, min_nonzero=62, uniform[chi2=90.13, dof=99, p=7.266e-01], vs_global[chi2=85.94, dof=99, p=8.223e-01]
#     pos 14: unique=100, max_count=103 (value=32), zero_bins=0, min_nonzero=60, uniform[chi2=93.86, dof=99, p=6.270e-01], vs_global[chi2=85.16, dof=99, p=8.379e-01]
#     pos 15: unique=100, max_count=104 (value=39), zero_bins=0, min_nonzero=64, uniform[chi2=99.89, dof=99, p=4.559e-01], vs_global[chi2=90.68, dof=99, p=7.127e-01]
#
# File: /Users/kevwjin/Documents/02_Areas/Sjsu/Fall2025/Cs228_BioSecAi/Research/artifacts/zh-llm-hist-len16-n8192-rep1.npz.checkpoint.npz
#   shape=(1280, 16), dtype=int64
#   min=1, max=102
#   unique rows=110, duplicate rows=46, duplicate entries=1216
#   global uniform test: chi2=73526.78, dof=101, p=0.000e+00
#   value frequency outliers (value, count, z):
#     1: count=1204, z=70.80
#     2: count=1042, z=59.37
#     3: count=1195, z=70.16
#     4: count=1055, z=60.28
#     5: count=1191, z=69.88
#     6: count=1053, z=60.14
#     7: count=1192, z=69.95
#     8: count=1053, z=60.14
#     9: count=1186, z=69.53
#     10: count=1055, z=60.28
#     11: count=1195, z=70.16
#     12: count=1054, z=60.21
#     13: count=1059, z=60.57
#     14: count=944, z=52.45
#     15: count=994, z=55.98
#     16: count=245, z=3.12
#     17: count=311, z=7.78
#     18: count=122, z=-5.56
#     19: count=260, z=4.18
#     20: count=128, z=-5.14
#     22: count=30, z=-12.05
#     23: count=154, z=-3.30
#     24: count=13, z=-13.25
#     25: count=148, z=-3.73
#     26: count=12, z=-13.32
#     27: count=145, z=-3.94
#     28: count=16, z=-13.04
#     29: count=146, z=-3.87
#     30: count=4, z=-13.89
#     31: count=144, z=-4.01
#     32: count=44, z=-11.06
#     33: count=30, z=-12.05
#     34: count=45, z=-10.99
#     35: count=28, z=-12.19
#     pos 5: unique=20, max_count=1039 (value=6), zero_bins=82, min_nonzero=1, uniform[chi2=86456.10, dof=101, p=0.000e+00], vs_global[chi2=16347.13, dof=98, p=0.000e+00]
#     pos 6: unique=25, max_count=1036 (value=7), zero_bins=77, min_nonzero=1, uniform[chi2=85917.25, dof=101, p=0.000e+00], vs_global[chi2=14399.58, dof=98, p=0.000e+00]
#     pos 7: unique=26, max_count=1036 (value=8), zero_bins=76, min_nonzero=1, uniform[chi2=85873.74, dof=101, p=0.000e+00], vs_global[chi2=16235.40, dof=98, p=0.000e+00]
#     pos 8: unique=28, max_count=1036 (value=9), zero_bins=74, min_nonzero=1, uniform[chi2=85894.30, dof=101, p=0.000e+00], vs_global[chi2=15142.12, dof=98, p=0.000e+00]
#     pos 9: unique=28, max_count=1036 (value=10), zero_bins=74, min_nonzero=1, uniform[chi2=85893.98, dof=101, p=0.000e+00], vs_global[chi2=17092.43, dof=98, p=0.000e+00]
#     pos 10: unique=28, max_count=1036 (value=11), zero_bins=74, min_nonzero=1, uniform[chi2=85872.78, dof=101, p=0.000e+00], vs_global[chi2=15343.71, dof=98, p=0.000e+00]
#     pos 11: unique=30, max_count=1036 (value=12), zero_bins=72, min_nonzero=1, uniform[chi2=85871.67, dof=101, p=0.000e+00], vs_global[chi2=17932.32, dof=98, p=0.000e+00]
#     pos 12: unique=37, max_count=899 (value=13), zero_bins=65, min_nonzero=1, uniform[chi2=65251.73, dof=101, p=0.000e+00], vs_global[chi2=14641.73, dof=98, p=0.000e+00]
#     pos 13: unique=39, max_count=899 (value=14), zero_bins=63, min_nonzero=1, uniform[chi2=65289.03, dof=101, p=0.000e+00], vs_global[chi2=15896.93, dof=98, p=0.000e+00]
#     pos 14: unique=42, max_count=826 (value=15), zero_bins=60, min_nonzero=1, uniform[chi2=55396.62, dof=101, p=0.000e+00], vs_global[chi2=13550.77, dof=98, p=0.000e+00]
#     pos 15: unique=41, max_count=426 (value=100), zero_bins=61, min_nonzero=1, uniform[chi2=19951.46, dof=101, p=0.000e+00], vs_global[chi2=14009.83, dof=98, p=0.000e+00]
#
# File: /Users/kevwjin/Documents/02_Areas/Sjsu/Fall2025/Cs228_BioSecAi/Research/artifacts/zh-llm-len16-n8192-rep1.npz
#   shape=(8192, 16), dtype=int64
#   min=1, max=121
#   unique rows=8007, duplicate rows=12, duplicate entries=197
#   global uniform test: chi2=248292.77, dof=120, p=0.000e+00
#   value frequency outliers (value, count, z):
#     1: count=2605, z=46.24
#     2: count=282, z=-24.34
#     3: count=324, z=-23.07
#     4: count=500, z=-17.72
#     5: count=697, z=-11.74
#     6: count=224, z=-26.11
#     7: count=677, z=-12.34
#     8: count=449, z=-19.27
#     9: count=486, z=-18.15
#     10: count=361, z=-21.94
#     11: count=2838, z=53.32
#     12: count=456, z=-19.06
#     13: count=6563, z=166.49
#     14: count=2076, z=30.16
#     15: count=641, z=-13.44
#     16: count=274, z=-24.59
#     18: count=1494, z=12.48
#     19: count=4199, z=94.67
#     20: count=72, z=-30.72
#     21: count=1242, z=4.82
#     22: count=906, z=-5.39
#     23: count=1895, z=24.66
#     24: count=951, z=-4.02
#     pos 2: unique=83, max_count=1507 (value=13), zero_bins=38, min_nonzero=1, uniform[chi2=68757.94, dof=120, p=0.000e+00], vs_global[chi2=12762.68, dof=102, p=0.000e+00]
#     pos 3: unique=92, max_count=1868 (value=67), zero_bins=29, min_nonzero=1, uniform[chi2=83256.14, dof=120, p=0.000e+00], vs_global[chi2=9388.62, dof=102, p=0.000e+00]
#     pos 4: unique=97, max_count=965 (value=67), zero_bins=24, min_nonzero=1, uniform[chi2=47200.74, dof=120, p=0.000e+00], vs_global[chi2=5281.37, dof=102, p=0.000e+00]
#     pos 5: unique=99, max_count=805 (value=85), zero_bins=22, min_nonzero=1, uniform[chi2=33334.66, dof=120, p=0.000e+00], vs_global[chi2=3398.26, dof=102, p=0.000e+00]
#     pos 6: unique=97, max_count=781 (value=85), zero_bins=24, min_nonzero=1, uniform[chi2=33745.22, dof=120, p=0.000e+00], vs_global[chi2=2716.98, dof=102, p=0.000e+00]
#     pos 7: unique=97, max_count=851 (value=85), zero_bins=24, min_nonzero=1, uniform[chi2=31696.88, dof=120, p=0.000e+00], vs_global[chi2=2426.14, dof=102, p=0.000e+00]
#     pos 8: unique=96, max_count=695 (value=31), zero_bins=25, min_nonzero=1, uniform[chi2=23215.18, dof=120, p=0.000e+00], vs_global[chi2=1817.10, dof=102, p=7.583e-312]
#     pos 9: unique=97, max_count=542 (value=31), zero_bins=24, min_nonzero=1, uniform[chi2=18880.04, dof=120, p=0.000e+00], vs_global[chi2=2155.29, dof=102, p=0.000e+00]
#     pos 10: unique=99, max_count=499 (value=46), zero_bins=22, min_nonzero=1, uniform[chi2=17077.36, dof=120, p=0.000e+00], vs_global[chi2=1909.09, dof=102, p=0.000e+00]
#     pos 11: unique=97, max_count=427 (value=46), zero_bins=24, min_nonzero=1, uniform[chi2=14787.16, dof=120, p=0.000e+00], vs_global[chi2=2466.62, dof=102, p=0.000e+00]
#     pos 12: unique=97, max_count=428 (value=46), zero_bins=24, min_nonzero=1, uniform[chi2=13121.84, dof=120, p=0.000e+00], vs_global[chi2=3245.86, dof=102, p=0.000e+00]
#     pos 13: unique=98, max_count=314 (value=39), zero_bins=23, min_nonzero=2, uniform[chi2=10821.63, dof=120, p=0.000e+00], vs_global[chi2=3477.34, dof=102, p=0.000e+00]
#     pos 14: unique=97, max_count=303 (value=39), zero_bins=24, min_nonzero=1, uniform[chi2=10262.98, dof=120, p=0.000e+00], vs_global[chi2=5406.70, dof=102, p=0.000e+00]
#     pos 15: unique=96, max_count=320 (value=93), zero_bins=25, min_nonzero=1, uniform[chi2=11239.84, dof=120, p=0.000e+00], vs_global[chi2=6701.77, dof=102, p=0.000e+00]
#
# File: /Users/kevwjin/Documents/02_Areas/Sjsu/Fall2025/Cs228_BioSecAi/Research/artifacts
#     pos 0: unique=40, max_count=2557 (value=1), zero_bins=61, min_nonzero=1, uniform[chi2=94176.48, dof=100, p=0.000e+00], vs_global[chi2=59085.70, dof=100, p=0.000e+00]
#     pos 1: unique=67, max_count=1717 (value=91), zero_bins=34, min_nonzero=1, uniform[chi2=63555.68, dof=100, p=0.000e+00], vs_global[chi2=24998.01, dof=100, p=0.000e+00]
#     pos 2: unique=84, max_count=1416 (value=13), zero_bins=17, min_nonzero=1, uniform[chi2=53141.33, dof=100, p=0.000e+00], vs_global[chi2=12162.00, dof=100, p=0.000e+00]
#     pos 3: unique=91, max_count=1843 (value=67), zero_bins=10, min_nonzero=1, uniform[chi2=68194.53, dof=100, p=0.000e+00], vs_global[chi2=9081.01, dof=100, p=0.000e+00]
#     pos 4: unique=93, max_count=992 (value=67), zero_bins=8, min_nonzero=1, uniform[chi2=37829.50, dof=100, p=0.000e+00], vs_global[chi2=4927.77, dof=100, p=0.000e+00]
#     pos 5: unique=98, max_count=852 (value=85), zero_bins=3, min_nonzero=1, uniform[chi2=29272.47, dof=100, p=0.000e+00], vs_global[chi2=3100.35, dof=100, p=0.000e+00]
#     pos 6: unique=95, max_count=801 (value=85), zero_bins=6, min_nonzero=1, uniform[chi2=28027.30, dof=100, p=0.000e+00], vs_global[chi2=2685.19, dof=100, p=0.000e+00]
#     pos 7: unique=96, max_count=862 (value=85), zero_bins=5, min_nonzero=1, uniform[chi2=25061.24, dof=100, p=0.000e+00], vs_global[chi2=2233.67, dof=100, p=0.000e+00]
#     pos 8: unique=97, max_count=740 (value=31), zero_bins=4, min_nonzero=1, uniform[chi2=19281.63, dof=100, p=0.000e+00], vs_global[chi2=1878.13, dof=100, p=0.000e+00]
#     pos 9: unique=99, max_count=548 (value=31), zero_bins=2, min_nonzero=1, uniform[chi2=14969.97, dof=100, p=0.000e+00], vs_global[chi2=1840.98, dof=100, p=0.000e+00]
#     pos 10: unique=100, max_count=479 (value=46), zero_bins=1, min_nonzero=1, uniform[chi2=13346.27, dof=100, p=0.000e+00], vs_global[chi2=1983.93, dof=100, p=0.000e+00]
#     pos 11: unique=98, max_count=440 (value=46), zero_bins=3, min_nonzero=1, uniform[chi2=10290.28, dof=100, p=0.000e+00], vs_global[chi2=2389.28, dof=100, p=0.000e+00]
#     pos 12: unique=98, max_count=445 (value=46), zero_bins=3, min_nonzero=1, uniform[chi2=9215.11, dof=100, p=0.000e+00], vs_global[chi2=3318.94, dof=100, p=0.000e+00]
#     pos 13: unique=99, max_count=335 (value=46), zero_bins=2, min_nonzero=1, uniform[chi2=7763.02, dof=100, p=0.000e+00], vs_global[chi2=3609.50, dof=100, p=0.000e+00]
#     pos 14: unique=96, max_count=308 (value=39), zero_bins=5, min_nonzero=1, uniform[chi2=7168.85, dof=100, p=0.000e+00], vs_global[chi2=5179.39, dof=100, p=0.000e+00]
#     pos 15: unique=98, max_count=366 (value=98), zero_bins=3, min_nonzero=1, uniform[chi2=8313.17, dof=100, p=0.000e+00], vs_global[chi2=6278.00, dof=100, p=0.000e+00]

# %%
for p in npz_paths:
    with np.load(p) as d:
        arr = d["sequences"]  # shape (N, 16)
    mask = (arr < 1) | (arr > 100)
    tokens_oor = int(mask.sum())
    seqs_oor = int(mask.any(axis=1).sum())
    total_tokens = arr.size
    print(
        f"{p.name}: tokens OOR={tokens_oor}/{total_tokens}, "
        f"seqs with any OOR={seqs_oor}/{arr.shape[0]}, "
        f"min={arr.min()}, max={arr.max()}"
    )
# Out:
# en-len16-n8192-rep1.npz: tokens OOR=0/131072, seqs with any OOR=0/8192, min=1, max=99
# en-len16-n8192-rep2.npz: tokens OOR=0/131072, seqs with any OOR=0/8192, min=1, max=99
# en-llm-hist-len16-n8192-rep1.npz: tokens OOR=0/131072, seqs with any OOR=0/8192, min=1, max=99
# en-llm-hist-len8-n8192-rep1.npz: tokens OOR=0/65536, seqs with any OOR=0/8192, min=1, max=99
# prng-len16-n8192-rep1.npz: tokens OOR=0/131072, seqs with any OOR=0/8192, min=1, max=100
# prng-len16-n8192-rep2.npz: tokens OOR=0/131072, seqs with any OOR=0/8192, min=1, max=100
# zh-llm-hist-len16-n8192-rep1.npz.checkpoint.npz: tokens OOR=45/20480, seqs with any OOR=42/1280, min=1, max=102
# zh-llm-len16-n8192-rep1.npz: tokens OOR=3/131072, seqs with any OOR=2/8192, min=1, max=121
# zh-llm-len16-n8192-rep2.npz: tokens OOR=1/131072, seqs with any OOR=1/8192, min=0, max=100

# %%
def plot_group(paths, title):
    fig, ax = plt.subplots(figsize=(8,4))
    for p in paths:
        arr = np.load(p)["sequences"]
        means = arr.mean(axis=0)
        ax.plot(range(len(means)), means, marker="o", label=p.stem)
    ax.set_xlabel("Position (0-indexed)")
    ax.set_ylabel("Mean value")
    ax.set_title(title)
    ax.legend()
    plt.show()

plot_group(sorted(len16_main), "Per-position means (len16 main)")
if len16_hist:
    plot_group(sorted(len16_hist), "Per-position means (len16 ZH history)")
if len8_hist:
    plot_group(sorted(len8_hist), "Per-position means (len8 EN history)")

# %%
# len16_main = []
# ax.set_xlabel("Integer value")
# ax.set_ylabel("Frequency")
# ax.set_title(title)
# ax.legend()
# plt.show()

def plot_group_hist(paths, title):
    fig, ax = plt.subplots(figsize=(8,4))
    for p in paths:
        arr = np.load(p)["sequences"]
        flat = arr.reshape(-1)
        min_v, max_v = int(flat.min()), int(flat.max())
        bins = max_v - min_v + 1
        counts, edges = np.histogram(flat, bins=bins, range=(min_v, max_v + 1))
        ax.bar(edges[:-1], counts, width=0.9, align="edge", edgecolor="black", alpha=0.4, label=p.stem)
    ax.set_xlabel("Integer value")
    ax.set_ylabel("Frequency")
    ax.set_title(title)
    ax.legend()
    plt.show()
    
len16_main = sorted(len16_main)
plot_group_hist(len16_main[:2], "Global hist (len16 EN)")
plot_group_hist(len16_main[3:5], "Global hist (len16 PRNG)")
plot_group_hist(len16_main[5:], "Global hist (len16 ZH)")
plot_group_hist(sorted(len16_hist), "Global hist (len16 ZH history)")
plot_group_hist(sorted(len8_hist), "Global hist (len8 EN history)")

# %%
# !python ../train_lstm_classifier.py --data ../artifacts/splits/en-split.npz --epochs 10 --batch-size 128
# !python ../train_lstm_classifier.py --data ../artifacts/splits/zh-split.npz --epochs 10 --batch-size 128
# !python ../train_lstm_classifier.py --data ../artifacts/splits/prng-split.npz --epochs 10 --batch-size 128
# Out:
# Traceback (most recent call last):
#   File "/Users/kevwjin/Documents/02_Areas/Sjsu/Fall2025/Cs228_BioSecAi/Research/notebooks/../train_lstm_classifier.py", line 11, in <module>
#     import numpy as np
# ModuleNotFoundError: No module named 'numpy'
# Traceback (most recent call last):
#   File "/Users/kevwjin/Documents/02_Areas/Sjsu/Fall2025/Cs228_BioSecAi/Research/notebooks/../train_lstm_classifier.py", line 11, in <module>
#     import numpy as np
# ModuleNotFoundError: No module named 'numpy'
# Traceback (most recent call last):
#   File "/Users/kevwjin/Documents/02_Areas/Sjsu/Fall2025/Cs228_BioSecAi/Research/notebooks/../train_lstm_classifier.py", line 11, in <module>
#     import numpy as np
# ModuleNotFoundError: No module named 'numpy'

# %%
# Run probe_losses via CLI to produce JSON
# !python ../probe_losses.py --en-split ../artifacts/splits/en-split.npz --zh-split ../artifacts/splits/zh-split.npz --prng-split ../artifacts/splits/prng-split.npz --en-model ../artifacts/en-split-lstm.pt --zh-model ../artifacts/zh-split-lstm.pt --prng-model ../artifacts/prng-split-lstm.pt --probe-count 1000 --out-json ../artifacts/probe_losses.json

with open("../artifacts/probe_losses.json") as f:
    results = json.load(f)
models = ["en","zh","prng"]
probes = ["en","zh","prng"]
df = pd.DataFrame([[results[m][p]["loss"] for p in probes] for m in models], index=models, columns=probes)

plt.figure(figsize=(5,4))
sns.heatmap(df, annot=True, fmt=".2f", cmap="magma_r")
plt.title("Probe losses (lower is better)")
plt.xlabel("Probe")
plt.ylabel("Model")
plt.show()
# Out:
# Traceback (most recent call last):
#   File "/Users/kevwjin/Documents/02_Areas/Sjsu/Fall2025/Cs228_BioSecAi/Research/notebooks/../probe_losses.py", line 9, in <module>
#     import numpy as np
# ModuleNotFoundError: No module named 'numpy'

# %%
# Generate JSON (adjust paths if needed)
# !python ../mixture_inference.py --en-split ../artifacts/splits/en-split.npz --zh-split ../artifacts/splits/zh-split.npz --en-model ../artifacts/en-split-lstm.pt --zh-model ../artifacts/zh-split-lstm.pt --probe-count 500 --out-json ../artifacts/mixture.json

with open("../artifacts/mixture.json") as f:
    mix_json = json.load(f)
dfm = pd.DataFrame(mix_json["rows"])
display(dfm)

plt.figure(figsize=(5,4))
plt.plot(dfm["true_en"], dfm["inferred_en"], marker="o", label="inferred")
plt.plot([0,1],[0,1], linestyle="--", color="gray", label="ideal")
plt.xlabel("True EN proportion")
plt.ylabel("Inferred EN proportion")
plt.legend()
plt.title("Mixture inference (loss-based)")
plt.show()
# Out:
# Traceback (most recent call last):
#   File "/Users/kevwjin/Documents/02_Areas/Sjsu/Fall2025/Cs228_BioSecAi/Research/notebooks/../mixture_inference.py", line 9, in <module>
#     import numpy as np
# ModuleNotFoundError: No module named 'numpy'
#    true_en   loss_en   loss_zh    acc_en    acc_zh  inferred_en
# 0     0.00  3.265832  5.329445  0.249867  0.024533     0.025351
# 1     0.25  3.053253  5.434221  0.272800  0.014933     0.281635
# 2     0.50  2.952430  5.432283  0.297067  0.021333     0.436629
# 3     0.75  2.736665  5.510635  0.308933  0.011467     0.714887
# 4     1.00  2.501532  5.559929  0.353467  0.010400     1.000000

# %%
from probe_gradients import load_model, create_loader, grad_vector
from train_lstm_classifier import get_device, load_split

ARTIFACTS = ROOT / "artifacts"
SPLITS = {
    "en": ARTIFACTS / "splits" / "en-split.npz",
    "zh": ARTIFACTS / "splits" / "zh-split.npz",
    "prng": ARTIFACTS / "splits" / "prng-split.npz",
}
CKPTS = {
    "en": ARTIFACTS / "en-split-lstm.pt",
    "zh": ARTIFACTS / "zh-split-lstm.pt",
    "prng": ARTIFACTS / "prng-split-lstm.pt",
}


def collect_grad_matrix(probe_count: int = 200, batch_size: int = 128) -> pd.DataFrame:
    """Mirror probe_gradients.py but return a dataframe for visualization."""
    device = get_device()
    criterion = nn.CrossEntropyLoss()
    rng = np.random.default_rng(42)

    specs: dict[str, dict[str, int]] = {}
    probes: dict[str, np.ndarray] = {}
    for name, split_path in SPLITS.items():
        tr, val, te = load_split(split_path)
        gmin = int(min(tr.min(), val.min(), te.min()))
        gmax = int(max(tr.max(), val.max(), te.max()))
        if probe_count and probe_count < te.shape[0]:
            te = te[rng.choice(te.shape[0], size=probe_count, replace=False)]
        specs[name] = {"shift": gmin, "vocab": gmax - gmin + 1}
        probes[name] = te

    models = {
        name: load_model(CKPTS[name], specs[name]["vocab"], 64, 128, 1, 0.1, device)
        for name in SPLITS
    }

    rows: list[dict[str, float | str]] = []
    for model_name, model in models.items():
        m_shift = specs[model_name]["shift"]
        m_vocab = specs[model_name]["vocab"]
        for probe_name, arr in probes.items():
            shifted = np.clip(arr - m_shift, 0, m_vocab - 1)
            loader = create_loader(shifted, batch_size)
            model.zero_grad(set_to_none=True)
            total_loss = 0.0
            total_tokens = 0
            for inputs, targets in loader:
                inputs = inputs.to(device)
                targets = targets.to(device)
                logits = model(inputs)
                loss = criterion(logits.view(-1, logits.size(-1)), targets.view(-1))
                loss.backward()
                total_loss += loss.item() * targets.numel()
                total_tokens += targets.numel()
            gvec = grad_vector(model)
            grad_norm = gvec.norm().item() if gvec.numel() else 0.0
            rows.append(
                {
                    "model": model_name,
                    "probe": probe_name,
                    "avg_loss": total_loss / total_tokens,
                    "grad_norm": grad_norm,
                }
            )
    return pd.DataFrame(rows)


def plot_grad_confusion(df: pd.DataFrame) -> None:
    """Pivot dataframe and display a confusion-matrix-style heatmap."""
    order = ["en", "zh", "prng"]
    mat = (
        df.pivot(index="model", columns="probe", values="grad_norm")
        .reindex(order, axis=0)
        .reindex(order, axis=1)
    )
    sns.heatmap(
        mat,
        annot=mat.applymap(lambda x: f"{x:.2f}"),
        fmt="",
        cmap="mako_r",
    )
    plt.title("Gradient Norm Confusion Matrix (darker = better match)")
    plt.ylabel("Model")
    plt.xlabel("Probe")
    plt.show()


if __name__ == "__main__":
    df = collect_grad_matrix()
    plot_grad_confusion(df)
# Out:
# /var/folders/zq/_48rsz752ql7ntbsr8hb1hr80000gn/T/ipykernel_93229/3783332926.py:80: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   annot=mat.applymap(lambda x: f"{x:.2f}"),

# %%
# Generate JSON (adjust paths if needed)
# !python ../mixture_inference_gradients.py \
  --en-split ../artifacts/splits/en-split.npz \
  --zh-split ../artifacts/splits/zh-split.npz \
  --en-model ../artifacts/en-split-lstm.pt \
  --zh-model ../artifacts/zh-split-lstm.pt \
  --probe-count 500 \
  --out-json ../artifacts/mixture_gradients.json

with open("../artifacts/mixture_gradients.json") as f:
  mix_json = json.load(f)

dfm = pd.DataFrame(mix_json["rows"])
display(dfm)

plt.figure(figsize=(5, 4))
plt.plot(dfm["true_en"], dfm["inferred_en"], marker="o",
label="inferred")
plt.plot([0, 1], [0, 1], linestyle="--", color="gray",
label="ideal")
plt.xlabel("True EN proportion")
plt.ylabel("Inferred EN proportion")
plt.legend()
plt.title("Mixture inference (gradient-based)")
plt.show()
# Out:
# Traceback (most recent call last):
#   File "/Users/kevwjin/Documents/02_Areas/Sjsu/Fall2025/Cs228_BioSecAi/Research/notebooks/../mixture_inference_gradients.py", line 9, in <module>
#     import numpy as np
# ModuleNotFoundError: No module named 'numpy'
#    true_en   loss_en   loss_zh   grad_en   grad_zh  inferred_en
# 0     0.00  3.265832  2.696261  2.664959  1.013756     0.021346
# 1     0.25  2.985922  2.763935  2.076173  1.296529     0.236756
# 2     0.50  2.918191  2.874998  1.584001  1.712893     0.460525
# 3     0.75  2.752783  2.887774  1.067535  2.618324     0.809107
# 4     1.00  2.570523  2.937694  1.080249  3.303290     0.972266

# %%
from mixture_notebook_helpers import run_and_display

df_loss = run_and_display("loss", probe_count=500)
df_grad = run_and_display("gradient", probe_count=500)
# Out:
# EN shift=0, vocab=99; ZH shift=0, vocab=121
# Fitted coeffs (bias, b_loss_en, c_loss_zh): [ 8.45699506 -1.52482893 -0.64768625]
# prop_en, loss_en, loss_zh, acc_en, acc_zh, inferred_en_prop
# 0.00, 3.2658, 5.3294, 0.250, 0.025, 0.025
# 0.25, 3.0533, 5.4342, 0.273, 0.015, 0.282
# 0.50, 2.9524, 5.4323, 0.297, 0.021, 0.437
# 0.75, 2.7367, 5.5106, 0.309, 0.011, 0.715
# 1.00, 2.5015, 5.5599, 0.353, 0.010, 1.000
# Saved mixture results to /Users/kevwjin/Documents/02_Areas/Sjsu/Fall2025/Cs228_BioSecAi/Research/artifacts/mixture.json
#    true_en   loss_en   loss_zh    acc_en    acc_zh  inferred_en
# 0     0.00  3.265832  5.329445  0.249867  0.024533     0.025351
# 1     0.25  3.053253  5.434221  0.272800  0.014933     0.281635
# 2     0.50  2.952430  5.432283  0.297067  0.021333     0.436629
# 3     0.75  2.736665  5.510635  0.308933  0.011467     0.714887
# 4     1.00  2.501532  5.559929  0.353467  0.010400     1.000000
# EN shift=0, vocab=99; ZH shift=-1, vocab=122
# Fitted coeffs (bias, b_grad_en, c_grad_zh): [ 0.43937429 -0.2492325   0.24282607]
# prop_en, grad_en, grad_zh, loss_en, loss_zh, inferred_en_prop
# 0.00, 2.6650, 1.0138, 3.2658, 2.6963, 0.021
# 0.25, 2.0762, 1.2965, 2.9859, 2.7639, 0.237
# 0.50, 1.5840, 1.7129, 2.9182, 2.8750, 0.461
# 0.75, 1.0675, 2.6183, 2.7528, 2.8878, 0.809
# 1.00, 1.0802, 3.3033, 2.5705, 2.9377, 0.972
# Saved mixture results to /Users/kevwjin/Documents/02_Areas/Sjsu/Fall2025/Cs228_BioSecAi/Research/artifacts/mixture_gradients.json
#    true_en   loss_en   loss_zh   grad_en   grad_zh  inferred_en
# 0     0.00  3.265832  2.696261  2.664959  1.013756     0.021346
# 1     0.25  2.985922  2.763935  2.076173  1.296529     0.236756
# 2     0.50  2.918191  2.874998  1.584001  1.712893     0.460525
# 3     0.75  2.752783  2.887774  1.067535  2.618324     0.809107
# 4     1.00  2.570523  2.937694  1.080249  3.303290     0.972266
